# %% [markdown]
# # EDA Data visualizations on Diabetic Data.

# %%
# Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
data=pd.read_csv(r"D:\Rajni\Files\Downloads\DS1_C4_S4_Insurance_Data_Concept.csv")

# %%
data
# Out:
#       patientid  dayofmonth  age  gender   bmi  bloodpressure diabetic  \
# 0             1          19   39    male  23.2             91      Yes
# 1             2           8   24    male  30.1             87       No
# 2             3          11   27    male  33.3             82      Yes
# 3             4           5   37    male  33.7             80       No
# 4             5          21   30    male  34.1            100       No
# ...         ...         ...  ...     ...   ...            ...      ...
# 1335       1336          27   44  female  35.5             88      Yes
# 1336       1337          15   59  female  38.1            120       No
# 1337       1338          27   30    male  34.5             91      Yes
# 1338       1339          15   37    male  30.4            106       No
# 1339       1340          10   30  female  47.4            101       No
#
#       children smoker     region     claim
# 0            0     No  southeast   1121.87
# ...

# %%
# Check the how many rows and how many columns in dataset.
data.shape
# Out:
# (1340, 11)

# %%
#It shows the how many rows and column, null or not null,data type
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   patientid      1340 non-null   int64
#  1   dayofmonth     1340 non-null   int64
#  2   age            1340 non-null   int64
#  3   gender         1340 non-null   object
#  4   bmi            1340 non-null   float64
#  5   bloodpressure  1340 non-null   int64
#  6   diabetic       1335 non-null   object
#  7   children       1340 non-null   int64
#  8   smoker         1340 non-null   object
#  9   region         1340 non-null   object
#  10  claim          1337 non-null   float64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 115.3+ KB

# %%
#How many null value in data.
data.isnull().sum()
#data.isnull().sum()/len(df3)*100 # Percentage of null value.
# Out:
# patientid        0
# dayofmonth       0
# age              0
# gender           0
# bmi              0
# bloodpressure    0
# diabetic         5
# children         0
# smoker           0
# region           0
# claim            3
# dtype: int64

# %%
#Replace Null Value with 0
data_filled = data.fillna(0)
#data_filled

# %%
data_filled.isnull().sum()
# Out:
# patientid        0
# dayofmonth       0
# age              0
# gender           0
# bmi              0
# bloodpressure    0
# diabetic         0
# children         0
# smoker           0
# region           0
# claim            0
# dtype: int64

# %%
# Display the first 5 rows of the dataset
data_filled.head()
# Out:
#    patientid  dayofmonth  age gender   bmi  bloodpressure diabetic  children  \
# 0          1          19   39   male  23.2             91      Yes         0
# 1          2           8   24   male  30.1             87       No         0
# 2          3          11   27   male  33.3             82      Yes         0
# 3          4           5   37   male  33.7             80       No         0
# 4          5          21   30   male  34.1            100       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51
# 2     No  southeast  1135.94
# 3     No  northwest  1136.40
# 4     No  northwest  1137.01

# %%
# Display the last 5 rows of the dataset
data_filled.tail()
# Out:
#       patientid  dayofmonth  age  gender   bmi  bloodpressure diabetic  \
# 1335       1336          27   44  female  35.5             88      Yes
# 1336       1337          15   59  female  38.1            120       No
# 1337       1338          27   30    male  34.5             91      Yes
# 1338       1339          15   37    male  30.4            106       No
# 1339       1340          10   30  female  47.4            101       No
#
#       children smoker     region     claim
# 1335         0    Yes  northwest  55135.40
# 1336         1    Yes  northeast  58571.07
# 1337         3    Yes  northwest  60021.40
# 1338         0    Yes  southeast  62592.87
# 1339         0    Yes  southeast  63770.43

# %%
#Initial Investigation of the data.(Summary statistics of numerical columns)
data_filled.describe().T
# Out:
#                 count          mean           std   min        25%       50%  \
# patientid      1340.0    670.500000    386.968991   1.0   335.7500   670.500
# dayofmonth     1340.0     15.145522      8.772054   1.0     7.0000    15.000
# age            1340.0     38.062687     11.094567  18.0    29.0000    37.500
# bmi            1340.0     30.657164      6.078581  16.0    26.2750    30.400
# bloodpressure  1340.0     94.149254     11.436618  80.0    86.0000    92.000
# children       1340.0      1.093284      1.205334   0.0     0.0000     1.000
# claim          1340.0  13164.758567  12058.351182   0.0  4687.4475  9296.015
#
#                      75%       max
# patientid       1005.250   1340.00
# dayofmonth        23.000     30.00
# age               47.000     60.00
# bmi               34.700     52.60
# bloodpressure     99.000    140.00
# children           2.000      5.00
# claim          16452.095  63770.43

# %%
# how many petaints age are greter than 47.
data_filled[data_filled['age']>47].shape[0]
# Out:
# 302

# %%
#value Counts....How many male and female in the data.
data_filled['gender'].value_counts() #How many male and female in the data.
data_filled['region'].value_counts()  #How many region in the data.
# Out:
# region
# southeast    443
# northwest    349
# southwest    317
# northeast    231
# Name: count, dtype: int64

# %%
#Maximum 10 claim value with use sorting
data_filled.sort_values(by='claim',ascending=False)[:10]
# Out:
#       patientid  dayofmonth  age  gender   bmi  bloodpressure diabetic  \
# 1339       1340          10   30  female  47.4            101       No
# 1338       1339          15   37    male  30.4            106       No
# 1337       1338          27   30    male  34.5             91      Yes
# 1336       1337          15   59  female  38.1            120       No
# 1335       1336          27   44  female  35.5             88      Yes
# 1334       1335          23   43    male  32.8            125       No
# 1333       1334          21   44    male  36.4            127       No
# 1332       1333          30   26    male  37.0            120       No
# 1330       1331           6   25  female  38.1            111       No
# 1329       1330          22   52  female  37.7            109      Yes
#
#       children smoker     region     claim
# 1339         0    Yes  southeast  63770.43
# 1338         0    Yes  southeast  62592.87
# 1337         3    Yes  northwest  60021.40
# ...

# %%
#Filter the data with Column gender,smoker,claim.
data_filled[(data_filled['gender']=='female') & (data_filled['smoker']=='Yes') & (data_filled['claim']>50000)]
# Out:
#       patientid  dayofmonth  age  gender   bmi  bloodpressure diabetic  \
# 1335       1336          27   44  female  35.5             88      Yes
# 1336       1337          15   59  female  38.1            120       No
# 1339       1340          10   30  female  47.4            101       No
#
#       children smoker     region     claim
# 1335         0    Yes  northwest  55135.40
# 1336         1    Yes  northeast  58571.07
# 1339         0    Yes  southeast  63770.43

# %%
# Filter the data with specific condition.
data_filled[data_filled['age'].between(18,25)]['claim'].sum()
# Out:
# 2584413.1600000006

# %%
# Visualize the Histograme plot of Age.
plt.figure(figsize=(10, 6))
sns.histplot(data_filled['claim'], kde=True)
plt.title('Histograme plot of Claim')
plt.xlabel('claim')
plt.ylabel('Frequency')
plt.show()

# %%
# Visualize the relationship between Age And Claim using Scatter Plot.
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='claim', data=data_filled)
plt.title('Relationship between Age and Claim')
plt.xlabel('age')
plt.ylabel('claim')
plt.show()

# %%
# Visualize the count of a Gender Using Count plot.
plt.figure(figsize=(10, 6))
sns.countplot(x='gender', data=data_filled)
plt.title('Count of Gender')
plt.xlabel('gender')
plt.ylabel('Count')
plt.show()
